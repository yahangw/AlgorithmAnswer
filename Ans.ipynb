# %% [markdown]
# # Practice
#
# 1.
#     A. insertion sort $\Theta(n^2)$
#
#     merge sort $\Theta(n\log{n})$
#
#     B. selection sort $\Theta(n^2)$
#
#     quicksort $\Theta(n^2)$
#
# 2.
#     A. $\Theta(n)$
#
#     B. $\Theta(n^2)$
#
#     C. $\Theta(\log{n})$
#
#     D. $\Theta(\log{(\log{n})})$
#
# 3.
#     DFS: acbhgfdxe
#     BFS: achxbgdfe
#
# 4. 11
#
# 5. <img src="image/img01.jpg" width="200">
#
# 6.
#     A. $O(n)$
#
#     B. $\Theta(n)$
#
#     C. $O(n^3)$
#
#     D. $O(n^2\log{n})$
#
# 7.
#     A. false
#
#     B. false
#
#     C. true
#
#     D. true
#
# 8.
#     A. <img src="image/img02.png" width="200">
#
#     B. Change the weight of each edge to its opposite number in G
#
# 9.
#     $f(n)=n+\frac{n}{2}+\frac{n}{4}+\cdots+1=\frac{1(1-2^{log_2{(n)}+1})}{1-2}=2\cdot 2^{\log_2n}-1=2n-1$
#
# 10.
#
#
# ```
# function DeleteSmallest(T)
#     if IsLeaf(T):
#         T = null
#     else if IsEmpty(T.left):
#         T = T.right
#     else:
#         DeleteSmallest(T.left)
# ```
#
# 11.
#
#
# ```
# max = -infty
# function FindMax(A[0..n-1])
#     if n>1:
#         mid = floor(n/2)
#         if A[mid] > max:
#             max = A[mid]
#         if A[mid] > A[0]:
#             return FindMax(A[mid+1..n-1])
#         else:
#             return FindMax(A[0..mid-1])
#     else:
#         return max
# ```
#
# 12.
#
# Both of them are correct and their time complexity is $\Theta(n)$.
#
# The number of comparisons for X is $2(n-1)+1$
#
# Best case for Y, the number of comparisons is $n+2$(ascending order)
#
# Worst case for Y, the number of comparisons is $2n+1$(descending order)
#
# # Sample
#
# 1. FILO FIFO
#
# 2.
#     1. Find the minimal
#     2. Comparison
#     3. 2n-1
#     4. $\Theta(n)$
#
# 3.
#     $\Theta(n^2\log{n})$
#
# 4. $O(n^2)$
#
# 5. $O(n\log{n})$
#
# 6.
#     a. false
#
#     b. false
#
#     c. true
#
#     d. false
#
# 8. false
#
# 9. Algorithm B
#
# 10.
#
# <img src="image/img03.jpeg" width="200">
#
# 11.
#     b. true false
#
# 12.
#
# b. If the tree is unbalanced, the efficiency can be degraded.
#
# c. <img src="image/img04.jpeg" width="200">
#
# d. <img src="image/img05.jpeg" width="200">
#
# 13.
#
# c. 4
#
# 14.
#
# ```
# function FindMax(T)
#     if Isleaf(T):
#         return T.root
#     else if IsEmpty(T.right):
#         return T.root
#     else:
#         return FindMax(T.right)
#
# function FindSecondMax(T)
#     if IsEmpty(T.right):
#         return FindMax(T.left)
#     else if IsLeaf(T.right):
#         return T.root
#     else:
#         return FindSecondMax(T.right)
# ```
#
# 15.
#     a. graph
#
#     b. minimal spanning tree
#
# 16.
#     a. 5
#
#     b. descending order n(n-1)/2
#
#     c. ascending order 0
#
#     d.
#
#
# Brute Force
# ```
# function FindInversion(A[0..n-1])
#     inversion = 0
#     for i=0 to n-2
#         for j = i+1 to n-1
#             if A[i] > a[j]
#                 inversion += 1
#     return inversion
# ```
#
# Divide and Conquer(tutorial 7 Q6)
#
#    e. for brute force $\Theta(n^2)$
#
#    for divide and conquer $\Theta(n\log{n})$
